# %%
from numpy.random import random_sample

d = {"col{:03d}".format(i): random_sample(200) for i in range(100) }
print(d)
# Out:
# {'col009': array([0.77573432, 0.50887246, 0.08251471, 0.60086531, 0.361829  ,
#        0.10014081, 0.92723656, 0.66673191, 0.51830156, 0.76585643,
#        0.42474899, 0.77638408, 0.82864435, 0.82641115, 0.27279427,
#        0.35578247, 0.74956394, 0.80094185, 0.9986573 , 0.20097757,
#        0.89102702, 0.39647997, 0.89945491, 0.29416918, 0.57051237,
#        0.24590813, 0.48827042, 0.23687821, 0.43108026, 0.84476506,
#        0.8768178 , 0.71136645, 0.91891016, 0.4474842 , 0.01275232,
#        0.51180696, 0.94559539, 0.91184445, 0.36567113, 0.91407373,
#        0.51227179, 0.16553414, 0.30869879, 0.46286363, 0.20533897,
#        0.17590408, 0.32731283, 0.26775847, 0.53333749, 0.23287174,
#        0.06027832, 0.77119788, 0.34359779, 0.38528026, 0.20032171,
#        0.20910714, 0.62053342, 0.92685521, 0.97476408, 0.3497165 ,
#        0.7584239 , 0.10917213, 0.0194255 , 0.08894975, 0.05931952,
#        0.97933848, 0.21540614, 0.63009793, 0.32717509, 0.46698639,
# ...

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

psql_data = pd.read_csv('column-data.csv')
rowtime = psql_data[["n rows", "time"]]
rowtime.boxplot(by="n rows")

# %%
psql_data = pd.read_csv('parquet-data.csv')
rowtime = psql_data[["n rows", "time"]]
rowtime.boxplot(by="n rows")
